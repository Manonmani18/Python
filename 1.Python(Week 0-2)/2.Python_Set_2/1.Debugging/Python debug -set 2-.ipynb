# %%
#1.Find the error in the following Python code:
import math
print(Math.sqrt(16))

# %%
import math
print(math.sqrt(16))

#have to use imported module
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
def my_function():
    x += 5
    print(x)

x = 10
my_function()

# %%
def my_function():
    x = 10
    x += 5
    print(x)
my_function()

#decalred in local variable inside the function
# Out:
# 15

# %%
#3.x = 5
if x = 10:
    print("x is 10")

# %%
x=5
if x == 5:
    print(f'{x} is 10')
#use comparision operator and used the formate string to print
# Out:
# 5 is 10

# %%
#4.
numbers = [5, 3, 8, 2]
print(numbers.sort())

# %%
numbers = [5, 3, 8, 2]
s=sorted(numbers)
print(s)
#sort the num using the sorted build in method
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    n * n

print(square(4))

# %%
def square(n):
   return n * n

print(square(4))

#return statement has been added
# Out:
# 16

# %%
#6.
my_tuple = (1, 2, 3)
my_tuple[1] = 5

# %%
my_tuple = (1, 2, 3)
convert_list=list(my_tuple)
convert_list.pop(1)
convert_list.insert(1,5)
print(tuple(convert_list))

#tuples are immutable to convered as list and pop the index1 value and insert the another value then convered as tuple
# Out:
# (1, 5, 3)

# %%
#7.
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name))

# %%
name = "Alice"
age = 25
print(f'My name is {name} and I am {age} years old')

#used formate string
# Out:
# My name is Alice and I am 25 years old

# %%
#8.
a = [1, 2, 3]
b = [1, 2, 3]
if a is b:
    print("Lists are equal")

# %%
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
#used comparision operator
# Out:
# Lists are equal

# %%
#9.
for i in range(5, 1):
    print(i)

# %%
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#10.
student = {"name": "John", "age": 20}
print(student[name])

# %%
student = {"name": "John", "age": 20}
print(student['name'])
# Out:
# John
