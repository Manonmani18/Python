# %%
# cenario: A system checks if a user is eligible to vote based on their age.
#  Write logic to ask the user for their age and determine if they are eligible to vote based on whether they are 18 or older.


age=int(input('Enter the age:'))
if age<18:
    print('Not Eligible to vote')
else:
    print('Eligible to vote')
# Out:
# Enter the age: 45
# Eligible to vote

# %%
# 2.	Scenario: A program processes a list of numbers and needs to find the largest value.
#  Write logic to identify and return the largest number from a given list.


def large():
    listNo=[13,23,55,66,99]
    sort=sorted(listNo)
    l=len(sort)
    # print(sort[l-1])
    return sort[l-1]
lno=large()
print('Largest no is:',lno)
# Out:
# Largest no is: 99

# %%
# 4.	Scenario: A program evaluates a number to determine if it is even or odd.
#  Write logic to check whether a given number is even or odd.


num=int(input('Enter no:'))
if(num%2==0):
    print('Even')
else:
    print('Odd')
# Out:
# Enter no: 10
# Even

# %%
# 5.	Scenario: A text-processing tool reverses a given word or sentence for formatting purposes.
#  Write logic to take a word or sentence as input and produce its reversed version.


string=str(input('Enter the string:'))
print(string[::-1])
# Out:
# Enter the string: manonmani
# inamnonam

# %%
# 6.	Scenario: A grading system determines whether a student has passed or failed based on their score.
#  Write logic to check if a student has passed a subject by scoring at least 40 marks.


sub1=int(input('Tamil:'))
sub2=int(input('English:'))
sub3=int(input('Maths:'))
sub4=int(input('Science:'))
sub5=int(input('Social Science:'))

if sub1>=40 and sub2>=40 and sub3>=40 and sub4>=40 and sub5>=40:
    print('pass')
else:
    print('fail')
# Out:
# Tamil: 12
# English: 45
# Maths: 78
# Science: 98
# Social Science: 65
# fail

# %%
# 7.	Scenario: A retail store offers a 20% discount if a customer’s total order exceeds $100. 
#     Write logic to calculate the final amount to be paid after applying the discount.

amount=int(input('enter the total order amount'))
# Sale Price = Original Price × (1 − Discount% / 100)
if amount>=100:
    final_amount=amount*(1-20/100)
    print(final_amount)
else:
    print('No Discount')
# Out:
# enter the total order amount 120
# 96.0

# %%
# Bonus Amount = Base Salary × Bonus Percentage ÷ 100
# 3.	Scenario: A company provides employees with a 10% bonus if their salary exceeds $50,000.
#  Write logic to determine the bonus amount based on the given salary.

basic_sal=int(input())
if basic_sal >= 50000:
    bonus = basic_sal * 10 / 100
    new_sal=basic_sal+bonus
    print(new_sal)
else:
    print('No bonus sorry...')
# Out:
#  20000
# No bonus sorry...

# %%
# 9.	Scenario: A calendar system verifies whether a given year is a leap year based on standard leap year rules.
#  Write logic to determine whether a given year is a leap year.


year=int(input('enter the year:'))
if year % 4 == 0:
    print(f'{year} is leap year')
else:
    print(f'{year} is not a leap year')
# Out:
# enter the year: 2000
# 2000 is leap year

# %%
# 10.	Scenario: A program filters out only even numbers from a given list.
#  Write logic to extract and return only the even numbers from a list.


def filterEven():
    lists=[12,13,14,15,16,20]
    even=list(filter(lambda x:x%2==0,lists))
    return even
result=filterEven()
print(result)
# Out:
# [12, 14, 16, 20]

# %%
# 8.	Scenario: A banking system processes withdrawal requests and ensures the user has
# enough balance. Write logic to check if a user has enough balance before allowing a withdrawal and update the remaining balance accordingly.
balance=10000
withdrawal=3000
if withdrawal <= balance:
    b=balance-withdrawal
    print('Withdrawal successful')
    print('Current balance:',b)
else:
    print('Insufficient funds')
# Out:
# Withdrawal successful
# Current balance: 7000
