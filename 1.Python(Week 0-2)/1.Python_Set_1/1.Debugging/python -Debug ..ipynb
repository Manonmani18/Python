# %%
# syntax error: there is no colon in the end of the for loop
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
# typeerror: concatenation only string not int , if we want to concatenate we can use fstring for str and int 
a=10
b=5
print(a+b)
# Out:
# 15

# %%
# syntax error: there is no colon in the end of the fun definition

def add_numbers(a, b):
    return a + b
add_numbers(1,2)
# Out:
# 3

# %%
# there is no index 4 in the list 
# indentation 
numbers = [1, 2, 3, 4]
print(numbers[3])
# Out:
# 4

# %%
# syntax error: open and close brackets are not there in print statement
print("Hello, World!")
# Out:
# Hello, World!

# %%
# x = 5 / 0
# here we div with 0 so we can get some division error
x=5
print(x)
# Out:
# 5

# %%
# Name error: we did not declare name variable so name is not defined
age = 25
name = 'mano'
print(f'Name:{name},Age:{age}')
# Out:
# Name:mano,Age:25

# %%
# no output - here step we have -1 so the start should bigger than stop

for i in range(1, 10):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
# syntax error: here assignment operator has been used so there is no logical operator

x = 10
if x == 5:
    print("x is 5")
else:
    print('x is not 5')
# Out:
# x is not 5

# %%
# syntax error: there is no colon in the end of the fun definition, and no function call

def greet(name):
    print("Hello, " + name)
greet('mano')
# Out:
# Hello, mano
