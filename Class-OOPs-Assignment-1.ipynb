# %%
class SubfieldsInAI():
    def Subfields():
        SubfieldsInAI = ['Machine Learning','Neural Networks','Vision','Robotics','Speech Processing','Natural Language Processing']
        print('Sub-fields in AI are:')
result=SubfieldsInAI.Subfields()
print(result)
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
# None

# %%
class OddEven():    
    def OddEven():       
        if(num % 2 == 0):
            return 'even'
        else:
            return 'odd'  
num = int(input('Enter a number:')) #declared as global var can access outside the fun
# result=OddEven() 
final=OddEven.OddEven() 
if (final == 'even'):
    print(f'{num} is Even number')
else:
    print(f'{num} is Odd number')
# Out:
# Enter a number: 25452
# 25452 is Even number

# %%
class ElegiblityForMarriage():
    def Elegible():
        if(gen == 'Male' and age > 21):
            return 'ELIGIBLE'
        elif(gen == 'Female' and age > 18):
            return 'ELIGIBLE'
        else:
            return 'NOT ELIGIBLE'
    gen = str(input('Your Gender:'))
    age = int(input('Your Age:'))
final=ElegiblityForMarriage.Elegible()
print(final)
# Out:
# Your Gender: Male
# Your Age: 20
# NOT ELIGIBLE

# %%
class FindPercent():
    def percentage():
        add=s1+s2+s3+s4+s5
        return add
    result = percentage()  
s1=int(input('Subject1='))
s2=int(input('Subject2='))
s3=int(input('Subject3='))
s4=int(input('Subject4='))
s5=int(input('Subject5='))
final=FindPercent.percentage()
print('Total:',final)
per=float(final/5)
print('Percentage:',per)
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage: 93.6

# %%
class triangle():
  def triangle(*args):
    print('Height:',args[0])
    print('Breadth:',args[1])
    print('Area of Triangle:',result[0])
    print('Height1:',args[2])
    print('Height2:',args[3])
    print('Breadth:',args[4])
    print('Area of perimeter:',result[1])
    area=(args[0]*args[1])/2
    perimeter=(args[2]+args[3]+args[4])
    return area,perimeter 
result = triangle.triangle(32,34,2,4,4)
# Out:
# Height: 32
# Breadth: 34
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Area of perimeter: 10
