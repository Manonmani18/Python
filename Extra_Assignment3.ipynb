# %%
v=10
print('value:',v)
if(v==10):
    print('Correct')
# Out:
# value: 10
# Correct

# %%
p='HOPE@123'
pwd=input('Enter the password:')
if(p==pwd):
    print('Your password is correct')
# Out:
# Enter the password: HOPE@123
# Your password is correct

# %%
age=int(input('age:'))
if(age<18):
    print('children')
elif(age<35):
    print('adult')
elif(age<59):
    print('citizen')
else:
    print('senior citizen')
# Out:
# age: 20
# adult

# %%
num=int(input('Enter any number:'))
print('No is positive') if(num>0) else print('No is negative')
# Out:
# Enter any number: 3
# No is positive

# %%
n=int(input('Enter a number to check:'))
print('No is divisible by 5') if(n%5==0) else print('No is not divisible by 5')
# Out:
# Enter a number to check: 22
# No is not divisible by 5
