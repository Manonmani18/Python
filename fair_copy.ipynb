# %%
from main import mulitipleFunctions

# %%
mulitipleFunctions.OddEven()
# Out:
# Enter a number: 52452
# '52452 is Even number'

# %%
mulitipleFunctions.percentage()
# Out:
# Subject1= 98
# Subject2= 87
# Subject3= 95
# Subject4= 95
# Subject5= 93
# Total: 468
# Percentage: 93.6

# %%
mulitipleFunctions.Elegible()
# Out:
# Your Gender: Male
# Your Age: 20
# 'NOT ELIGIBLE'

# %%
mulitipleFunctions.triangle(32,34,2,4,4)
# Out:
# Height: 32
# Breadth: 34
# Area of Triangle: 544.0
# Height1: 2
# Height2: 4
# Breadth: 4
# Area of perimeter: 10

# %%
mulitipleFunctions.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing
