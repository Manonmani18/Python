# %%
print('HOPE AI')
# Out:
# HOPE AI

# %%
iName=str(input('Enter your institute name? :'))
print(iName)
# Out:
# Enter your institute name? : HOPE AI
# HOPE AI

# %%
name=str(input('Enter your name:'))
age=int(input('Enter your age:'))
sName=str(input('Enter your school name:'))
degree=str(input('Enter your drgree:'))
# Out:
# Enter your name: Raj
# Enter your age: 15
# Enter your school name: Guru school
# Enter your drgree: B.E CSE

# %%
a=43
b=34
add=a+b
print(f'a={a}') #here im using formate string
print(f'a={b}')
print(f'add={add}')
# Out:
# a=43
# a=34
# add=77

# %%
a=43
b=34
sub=a-b
print(f'a={a}')
print(f'b={b}')
print(f'sub={sub}')
# Out:
# a=43
# b=34
# sub=9

# %%
a=63
b=97
mul=a*b
print(f'a={a}')
print(f'b={b}')
print(f'Mul={mul}')
# Out:
# a=63
# b=97
# Mul=6111

# %%
a= 76 
b= 31 
div=a/b
print(f'a={a}')
print(f'b={b}')
print(f'Float Div={div}')
# Out:
# a=76
# b=31
# Float Div=2.4516129032258065

# %%
a= 76 
b= 31 
fDiv=a//b
print(f'a={a}')
print(f'b={b}')
print(f'Floor Div={fDiv}')
# Out:
# a=76
# b=31
# Floor Div=2

# %%
a= 76 
b= 31 
mod=a%b
print(f'a={a}')
print(f'b={b}')
print(f'Modulo={mod}')
# Out:
# a=76
# b=31
# Modulo=14

# %%
a=4
b=4
expo=a**b
print(f'a={a}')
print(f'b={b}')
print(f'Power={expo}')
# Out:
# a=4
# b=4
# Power=256
