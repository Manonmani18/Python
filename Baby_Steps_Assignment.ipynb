# %%
print('Welcome to Assignment-1')
# Out:
# Welcome to Assignment-1

# %%
num1=10
num2=30
add=num1+num2
print('Num1=',num1)
print('Num2=',num2)
print('Add=',add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
#multiple conditions in one line
user=int(input('Enter the BMI Index:'))
print('Underweight') if (user<18.4) else print('Normal') if (user<25.9) else print('Overweight') if (user<29.9) else print('Obesity')
# Out:
# Enter the BMI Index: 30
# Obesity

# %%
user=int(input('Enter the BMI Index:'))
if(user<18.4):
    print('Underweight')
elif(user<25.9):
    print('Normal')
elif(user<29.9):
    print('Overweight')
else:
    print('Obesity')
# Out:
# Enter the BMI Index: 17
# Underweight
